# %% [markdown]
# <a href="https://colab.research.google.com/github/oshendera/Movie-Review-/blob/MovieReview/Beni_imdb_movie_reviews_research_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title and Basic Info
#
# **Title:** IMDB Movies Reviews Dataset
#
# **Auther name:** Beni Shendera
#
# **Date:** july 11, 2025

# %% [markdown]
# ##Research Questions
#
# 1. How do sentiment trends of top IMDb-rated movies evolve from 2015 to 2024?
#
# 2. What relationship exists between user ratings (stars) and review sentiment polarity?
#
# 3. Do certain genres or years yield more extreme sentiment (positive/negative)?
#
# 4. How do review lengths correlate with positivity or negativity?
# Can we predict review sentiment using textual features?

# %% [markdown]
# ##Hypotheis
#
# H₁: Average sentiment has increased over time: recent movies are reviewed more positively.
#
# H₂: Positive text sentiment strongly correlates with higher star ratings.
#
# H₃: Specific genres (e.g., horror) show more polarized sentiment than family-oriented movies.
#
# H₄: Longer reviews are more likely to show nuanced (neutral or mixed) sentiment.
#
# H₅: Prediction models (e.g. logistic regression) can classify sentiment with ≥85% accuracy.

# %% [markdown]
# ##Background Research
#
# Important finding 1: Maas et al. analyzed 50k polarized IMDb reviews and showed 25k positive/negative labeling is effective for sentiment classification
#
# Important finding 2: Modeled with logistic/regression and TF-IDF, balanced accuracy around 88-95%
# ijisrt.com
#
# Important finding 3: CNN and LSTM models (e.g. Bagheri, Taha533) on same dataset achieved high accuracies; deep learning outperforms traditional methods
# Alireza Bagheri | Data Scientist
#
# Important finding 4: BERT+BiLSTM fine-tuning achieves -97.7% accuracy on binary sentiment classification on IMDb dataset
#
# Important finding 5: Lexicon and Naïve Bayes methods benefit from handling negation and n-grams—boosts performance (-88.8% accuracy)
# arXiv
#
# **Gap my research  fill**:
#
# **Temporal variation**: No existing study focuses on year-over-year sentiment trends for top IMDb-reviewed movies (2015–2024).
#
# **Additional metadata analysis**: Few works incorporate regression on review length, genres, or year.
#
# **Relevant context**:
#
# IMDb review datasets are widely used benchmarks, but there’s room to explore meta-level trends over time and across genres.

# %% [markdown]
# ##Data Source Info
#
# **Source**:	Kaggle dataset from Shivvm Vince, collating IMDb reviews for top movies (2015–2024)
#
# **Collection method**:	 from IMDb, curated “featured” reviews on top‑25 yearly titles
#
#
# **Time period**:	Covers 2015–2024
#
#
# **Sample size**:	-25 movies/year × reviews count
#
#
# **Variables**:	Movie title, year, review text, user rating, date
#
#
# **Data quality issues**:	Possible missing metadata (e.g., reviewer details); inconsistencies in rating scale; possibly imbalanced reviews by year
#
#
# **Ethical concerns**:	Publicly posted reviews; no PII; fair-use for research likely acceptable
#
#
# **Limitations**:	Only featured top‑25 movies/year → not representative; no demographic reviewer info; dataset is limited to certain movies and years

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set visualization style
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Load datasets
try:
    imdb_list_df = pd.read_csv('/content/imdb_list.csv')
    print("Loaded imdb_list.csv successfully.")
    display(imdb_list_df.head())
except FileNotFoundError:
    print("Error: imdb_list.csv not found.")
except Exception as e:
    print(f"Error loading imdb_list.csv: {e}")

try:
    imdb_reviews_df = pd.read_csv('/content/imdb_reviews.csv')
    print("\nLoaded imdb_reviews.csv successfully.")
    display(imdb_reviews_df.head())
except FileNotFoundError:
    print("Error: imdb_reviews.csv not found.")
except Exception as e:
    print(f"Error loading imdb_reviews.csv: {e}")

# Placeholder for merging or processing the dataframes
# Depending on your analysis plan, you might need to merge or process these dataframes.
# Example: df = pd.merge(imdb_list_df, imdb_reviews_df, on='some_column', how='inner')
# For now, we will continue with imdb_reviews_df for sentiment analysis as it contains the review text.
df = imdb_reviews_df
# Out:
# Loaded imdb_list.csv successfully.
#    Unnamed: 0         id                               title  rating  \
# 0           0  tt0369610                      Jurassic World     6.9
# 1           1  tt3774694                                Love     6.1
# 2           2  tt2361509                          The Intern     7.1
# 3           3  tt2381249  Mission: Impossible - Rogue Nation     7.4
# 4           4  tt3460252                   The Hateful Eight     7.8
#
#                          genre  year
# 0    Action, Adventure, Sci-Fi  2015
# 1               Drama, Romance  2015
# 2                Comedy, Drama  2015
# 3  Action, Adventure, Thriller  2015
# 4        Crime, Drama, Mystery  2015
# Loaded imdb_reviews.csv successfully.
#      imdb_id                                       review title  \
# 0  tt0369610  Spielberg Magic, This Is Not. Still, a Visit t...
# 1  tt0369610  Not a patch on the original Jurassic Park, and...
# ...

# %% [markdown]
# ##EDA & Analysis Plan
#
# **Variables to Examine**:
#
# **Text:** review sentiment/polarity
#
# **Numeric:** star rating, review length, date
#
#
# **Categorical:** movie title, year, inferred genre (if available)
#
# **Relationshiops to Explore**:
#
# 1. Sentiment <> star rating correlation
#
#
# 2. Sentiment/time across years
#
#
# 3. Sentiment/length associations
#
#
# 4. Possible sentiment differences across genres
#
# **Visualizations**:
# 1. Histogram/density of sentiment polarity
#
#
# 2. **Scatter plot**: sentiment vs. star rating
#
# 2. Line chart of average sentiment by year
#
# 3. Bar chart comparing sentiment across genres
#
# 4. Correlation heatmap
#
# **Statistical Tests**
#
# 1. Pearson/Spearman correlations
#
# 2. ANOVA or t-tests between groups
#
# 3. Regression models to predict ratings from sentiment
#
# **Connection to Research Questions**:
#
# Each stat test and plot addresses how sentiment relates to time, rating, and genre.

# %% [markdown]
# ##Initial check
#
# **Cleanliness**: missing/null?
#
#
# **Data types**: text, numeric, date
#
#
# **Shape**: rows × columns count
#
#
# **Basic stats**: rating distributions, review lengths

# %% [markdown]
# #Visualizations & Code
#
#
# **Univariate**: histogram of ratings; polarity values; boxplots to detect outliers
#
#
# **Bivariate**: scatter sentiments vs. ratings; correlation matrices
#
#
# **Comparisons**: genres average sentiment; year-by-year sentiment trends
#
#
# **Summary chart**: line plot of average sentiment over years with confidence intervals

# %% [markdown]
# #Statistical Testing & Results Summary
#
#
# **Correlation**: r between sentiment score and star rating
#
#
# **ANOVA**: comparing average sentiment across years or genres
#
#
# **Classifier**: logistic regression accuracy with p-values
#
# **Results**: Include numbers, p-values, interpretation and link back to research questions.

# %% [markdown]
# ##Discussion Notes
#
# **Interpretation**: What do your findings mean? E.g., a rising sentiment trend suggests positive review bias over time.
#
# **Comparison with Lit**: Compare model accuracy with prior 88–97.7% benchmarks.
#
# **Limitations**: Non-representative sample, limited metadata, review bias.
#
# **Implications**: Industry insights, review understanding, film marketing strategy
#
# **Future**: Add genre tags, demographic data; use multimodal analysis (text + audio/image).

# %% [markdown]
# ##Conclusion Notes
#
# Reiterate research question.
#
# Summarize key data-driven findings.
#
# Explain significance.
#
# Suggest future expansion (e.g., use entire IMDb, scrape more years).

# %% [markdown]
# ##Abstract Draft
#
# **Research Question**: This study investigates how sentiment in IMDb movie reviews for top-25 films has evolved from 2015 through 2024, and how it relates to ratings and review features.
#
# **Methods**: I analyze X,XXX featured reviews (scraped from IMDb via Kakgle), perform sentiment scoring via TF-IDF and logistic regression, and assess trends across time and metadata.
#
# **Key Findings**: I observe a significant positive correlation (r=…) between sentiment scores and star ratings; average sentiment increased from 2015 to 2024
# (p<0.05); certain genres exhibit more polarized reviews.
#
#
# **Significance**: These results extend previous work by situating sentiment analysis in a temporal and genre-based context, highlighting review bias and evolving viewer expectations over time.
